# %% [markdown]
# ---
# layout: post
# title: Sprint 3
# categories: [Collaboration]
# courses: {csa: {week: 12} }
# type: collab
# comments: true
# ---

# %% [markdown]
# ## Final Introduction
# Teacher and peer evaluation are critical to our success and improvement. Ensure to support each meeting’s objectives by performing self-reviews, providing feedback to peers, and acting on feedback from teachers and peers. A key way to support dialogue is by providing a Review Ticket (GitHub Issues and/or GitHub Pages Utterance).
#
# ---
#
# ## Individual Issues
# Document your journey in all sprints with personal issues or blogs. By the end of this period, ensure to have issues/blogs for:
# - [Sprint 1](https://github.com/alishahussain/alisha2025/issues/3)
# - [Sprint 2](https://alishahussain.github.io/alishanew2025/collaboration/2024/10/08/sprint2_IPYNB_2_.html)
#
# ---
#
# ## Team Issue(s)
# Collaboration requires team-assigned issues. Each issue should reflect:
# 1. **Ideation**
# 2. **Development**
# 3. **Integration (Pull Request)**
# 4. **Test Validation**
# [Team Teach Group Planning](https://github.com/alishahussain/alishanew2025/issues/3)
# [SeedTracker Group Planning](https://github.com/sharonkodali/seedtracker_front/issues/1)
#
# ---
#
# ## Preparation
# Refer to the checklist for guidelines, keeping in mind that:
# - **Summarize** information effectively for the teacher.
# - **Present and self-evaluate** to highlight your contributions.
#
# ---
#
# ## Final Evaluation
#
# ### Assignments Evaluation
#
#
# | **Assignment**                | **Points**    | **Grade** | **Evidence** |
# |-------------------------------|---------------|-----------|--------------|
# | Tri 1-3 Review Ticket         | 3             |    3       |              |
# | Sprint 3 Team Issue(s)/Plan   | 2             |    2       |[Link to Issue](https://github.com/sharonkodali/seedtracker_front/issues/1)              |
# | Beginning-2-End Contribution  | 2             |    2       |[Pull Request on Main](https://github.com/Imaad08/NITD_2025/pull/3/commits)  [Created Backend](https://github.com/CSA-Coders-2025/CSA_Combined_Backend_Fork/commit/13c5ad0d6d4ad4cfaafbd9ed466cd2508df99427)              |
# | N@tM Team Presentation        | 2             |    2       | [Feedback Form](https://docs.google.com/spreadsheets/d/1am25uqxQV-obt5aMHrG5grQI9OKg10wtAkFuVd8zYfI/edit?gid=1566378001#gid=1566378001)             |
# | Live Review Indi Demo         | 1             |    TBD       |              |
# | **Total**                     | 10            |    TBD       |              |
#
# | **Skill**                  | **Points**    | **Grade** | **Evidence** |
# |----------------------------|---------------|-----------|--------------|
# | Work Habits (Analytics)    | 1             |     1      | <img width="821" alt="Screenshot 2024-11-11 at 5 46 07 PM" src="https://media.discordapp.net/attachments/1086819477204766761/1306298054378393651/Screenshot_2024-11-13_at_8.42.01_AM.png?ex=6736285e&is=6734d6de&hm=3e3f25459818f293d6bc652e0dbaf121ad27c5f0223bb4d2b628d9e7aa47028a&=&format=webp&quality=lossless&width=2160&height=900">             |
# | Evidence of Role in Team   | 1             |      1     |              |
# | Function / Purpose Design  | 1             |       1    | <img width="721" alt="Screenshot 2024-11-11 at 5 45 04 PM" src="https://cdn.discordapp.com/attachments/1086819477204766761/1306299257405575279/Screenshot_2024-11-13_at_8.46.29_AM.png?ex=6736297c&is=6734d7fc&hm=2de13c9476765c9807359d4c727ecda1a8ced432cad807b7e488b453f6dd7bf6&">             |
# | Live Review                | 2             |     TBD     |              |
# | **Total**                  | 5             |     TBD      |              |
#
# ---
#
# ## Tri 1-3 Review Ticket
# Showcase your accomplishments for the trimester, including:
#
# 1. **Tools Mastery**
#    - Describe tools you've mastered and examples of effective use.
#       - During this trimester, I have mastered using postman, VScode, terminal, UML, and github. In CSP I gained a little bit of familiarity with all of these tools but I was still unsure with how to use them. This trimester, while integrating with my new team, I learned how useful these can be when making something that requires an API, especially postman. Postman was really useful to me when testing out my endpoints before developing a frontend that didn't wotk and then having to change the entire thing. it was really interesting to learn how to analzye the message bodies and see how they are actually working with the game. I also had to deal with a lot of troubleshooting with my game, so using console logs and run + debug was really useful. Being able to solve those problemswas really satisfying for me! Additionaly, I learned how to make pull requests on github, and do things like deal with merge conflits, which had to be done often given we were working with a large team.
# 2. **Programming Skills**
#    - Demonstrate your skill in the programming languages used.
#       - This trimester I leanred how to do backend API work with Java, which I've never done before. I have a little bit of prior experience with Java, but that was just making small turtle games, so it eas interesting to see how that knowledge helped me make an actual fullstack game. I gained even more experience with frontend work, which I felt i was already okay in.
# 3. **College Board Requirements**
#    - Provide examples aligning your work with AP CSA standards.
#       - [Collegeboard Units Reference](https://alishahussain.github.io/alishanew2025/collaboration/2024/10/10/sprint2.1_IPYNB_2_.html)
#       - In the beginnning of the tri, with all the team teaches, I was able to apply many different units of work, primarity with constructors and classes
#
# ---
#
# ## Sprint 3 Team Issue / Plan
# Highlight collaboration in your project, including:
# 1. **Iteration and Improvement**
#    - <img width="40" alt="Screenshot 2024-11-11 at 5 58 35 PM" src="https://github.com/user-attachments/assets/808242b6-c35b-4112-bca2-693d5d6f464a">
# 2. **Think-Pair-Share**
#    - [Ideation](https://github.com/dino596/gambling/issues/2)
# 3. **Online Collaboration Tools**
#    - <img width="57" alt="Screenshot 2024-11-11 at 5 58 47 PM" src="https://github.com/user-attachments/assets/91020e2f-1e07-4c83-8476-0284506e3575">
#
# ---
#
# ## Program Function and Purpose
# 1. **Project Purpose**
#    - Describe the purpose and innovation category.
#    - The purpose of our project
# 2. **Understanding and Development**
#    - Describe how understanding the project improved development.
#    - All the Scrum masters meeting up and deciding how the game would work out.  This really improved the devlopment of the project
# 3. **Inputs, Events, Outputs**
#    - Explain inputs, events, and outputs.
# 4. **User Interface Design and Data Definition**
#    - Show the UI and data definitions.
# 5. **Individual Coding Knowledge**
#    - Document personal code contributions in both frontend and backend.
#    - [Frontend](https://github.com/CSA-Coders-2025/CSA_Combined_Frontend_Fork/commits/GamblingFrontend%2BGame/)
#    - [Backend](https://github.com/Imaad08/NITD_2025/commits/TeamHanlunArthurAlishaSaaras/)
#
# ---
#
# ## Beginning-2-End Contribution
# Document your role in program design, development, and team collaboration:
#
# 1. **Development Process (Agile Scrum)**
# 2. **Design / Storyboard**
# 3. **Prototype / Experiments**
# 4. **Code Organization**
# 5. **Testing / Automation**
# 6. **Iterative Changes**
# 7. **Feedback and Corrections**
#
# ---
#
# ## Program Function and Purpose Evidences
# Describe the program's function and user interface. List key user interactions and outputs.
#
# ---
#
# ## Night at the Museum (N@tM) Presentation Feedback
# 1. **Presentation Overview**
#    - The NATM presentation was a big learnign expereince for me. I learned to present and work in a group where I did not previsouly know the people which is differt than the groups I have been in before. We learned how to fix small errors we had liek a lack of the rightc calble so we had to screen share on zoom and use a few differnt computers.
# 2. **Audience Feedback**
#    - We stayes for almost 1.5 hours we were able to present to many people with differnt backgrounds, and overall we learned how to perfect out 'pitch' for the correct audience
#       - [Feedback Form Responses](https://docs.google.com/forms/d/1KK66rI-xgPkSNtbDa79U4tlO7juUABxkVsgqR1VC7kY/edit#responses)
# 3. **Questions and Answers**
#    - Document audience questions and responses.
#       - Some of the audience had questios on our autogeneratedID and how the student will be able to know what their own ID is so this is something we added on to our project
# 4. **Demonstration and Interaction**
#    - We were efficiently able to move through the frontend and backend and we allowed the audeince to test out our seedtracker to see their developments.
# 5. **Reflections and Improvements**
#    - In the future, we want to make sure to have the correct cables and everythning before we start out rpesentation. I also want to make sure tat I am not the only one in the group with thorough knowledge of the project.
#
# ---
#
# ## Live Review
# Prepare a 1-2 minute summary covering:
#
# 1. **Project Overview**
# 2. **Collaboration Evidences**
# 3. **Program Function and Purpose**
# 4. **Night at the Museum (N@tM) Feedback**
#
# ---
#
# ### Summary
# - **Project Overview**: Describe project, objectives, and features.
# - **Collaboration Evidences**: Describe development process and feedback.
# - **Program Function and Purpose**: Overview of user interactions and outputs.
# - **N@tM Feedback**: Summarize audience feedback and reflections.
#
#
#
# ---
#
# ## Extra
#
# - <img width="40" alt="Screenshot 2024-11-11 at 5 58 35 PM" src="https://cdn.discordapp.com/attachments/1086819477204766761/1306299462351585302/Screenshot_2024-11-13_at_8.47.34_AM.png?ex=673629ad&is=6734d82d&hm=33c21f23027102c261518ad1c1b6d955b0a32b4c291762fecda884a94b1eccf1&">
# - <img width="40" alt="Screenshot 2024-11-11 at 5 58 35 PM" src="https://cdn.discordapp.com/attachments/1086819477204766761/1306299532123967563/Screenshot_2024-11-13_at_8.47.53_AM.png?ex=673629be&is=6734d83e&hm=db6e44f756fce66ecd5f28a89a7fccb8fdb9ee2ab8a762c1c2690b8ab7a882d3&">
